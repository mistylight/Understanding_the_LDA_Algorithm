# %% [markdown]
# # LDA Training
# <figure>
# <img src=https://s2.loli.net/2022/02/28/X7vzOlDHJtP6UnM.png style="width: 600px">
# <figcaption>The LDA training algorithm from <a href=http://www.arbylon.net/publications/text-est.pdf>Parameter estimation for text analysis</a></figcaption>
# </figure>

# %%
import random
import numpy as np
from collections import defaultdict, OrderedDict
from types import SimpleNamespace
from tqdm.notebook import tqdm

# %%
# === corpus loading ===
class NeurIPSCorpus:
    def __init__(self, data_path, num_topics, max_num_docs=100, max_num_words=10000, max_doc_length=1000):
        self.docs = []
        self.word2id = OrderedDict()
        self.max_doc_length = max_doc_length

        word2cnt = defaultdict(int)
        with open(data_path) as fin:
            for i, line in enumerate(list(fin)[::-1]):  # use more recent papers
                if i >= max_num_docs: break
                for word in line.strip().split():
                    word2cnt[word] += 1
        
        word2cnt = sorted(list(word2cnt.items()), key=lambda x: x[1], reverse=True)
        if len(word2cnt) > max_num_words:
            word2cnt = word2cnt[:max_num_words]
        word2cnt = dict(word2cnt)

        with open(data_path) as fin:
            for i, line in enumerate(list(fin)[::-1]):  # use more recent papers
                if i >= max_num_docs: break
                doc = []
                for word in line.strip().split():
                    if len(doc) >= self.max_doc_length: break
                    if word not in word2cnt: continue
                    if word not in self.word2id: 
                        self.word2id[word] = len(self.word2id)
                    doc.append(self.word2id[word])
                self.docs.append(doc)

        self.num_docs = len(self.docs)
        self.num_topics = num_topics
        self.num_words = len(self.word2id)
        self.id2word = {v: k for k, v in self.word2id.items()}
        print(
            "num_docs:", self.num_docs, 
            "num_topics:", self.num_topics, 
            "num_words:", self.num_words
        )

corpus = NeurIPSCorpus(
    data_path="data/papers.txt", 
    num_topics=10,
    max_num_docs=1000,
    max_num_words=10000,
    max_doc_length=200,
)
hparams = SimpleNamespace(
    alpha=np.ones([corpus.num_topics], dtype=float) / corpus.num_topics,
    beta = np.ones([corpus.num_words], dtype=float) / corpus.num_topics,
    gibbs_sampling_max_iters=1000,
)
# Out:
# num_docs: 1000 num_topics: 10 num_words: 7794

# %%
# === initialization ===
print("Initializing...", flush=True)
n_doc_topic = np.zeros([corpus.num_docs, corpus.num_topics], dtype=float) # n_m^(k)
n_topic_word = np.zeros([corpus.num_topics, corpus.num_words], dtype=float) # n_k^(t)
z_doc_word = np.zeros([corpus.num_docs, corpus.max_doc_length], dtype=int)

for doc_i in range(corpus.num_docs):
    for j, word_j in enumerate(corpus.docs[doc_i]):
        topic_ij = random.randint(0, corpus.num_topics - 1)
        n_doc_topic[doc_i, topic_ij] += 1
        n_topic_word[topic_ij, word_j] += 1
        z_doc_word[doc_i, j] = topic_ij

# === Gibbs sampling ===
print("Gibbs sampling...", flush=True)
for iteration in tqdm(range(hparams.gibbs_sampling_max_iters)):
    for doc_i in range(corpus.num_docs):
        for j, word_j in enumerate(corpus.docs[doc_i]):
            # remove the old assignment
            topic_ij = z_doc_word[doc_i, j]
            n_doc_topic[doc_i, topic_ij] -= 1
            n_topic_word[topic_ij, word_j] -= 1
            # compute the new assignment
            p_doc_topic = (n_doc_topic[doc_i, :] + hparams.alpha) \
                        / np.sum(n_doc_topic[doc_i] + hparams.alpha)
            p_topic_word = (n_topic_word[:, word_j] + hparams.beta[word_j]) \
                        / np.sum(n_topic_word + hparams.beta, axis=1)
            p_topic = p_doc_topic * p_topic_word
            p_topic /= np.sum(p_topic)
            # record the new assignment
            new_topic_ij = np.random.choice(np.arange(corpus.num_topics), p=p_topic)
            n_doc_topic[doc_i, new_topic_ij] += 1
            n_topic_word[new_topic_ij, word_j] += 1
            z_doc_word[doc_i, j] = new_topic_ij

    if iteration % 10 == 0:
        print(f"Iter [{iteration}]===")
        # === Check convergence and read out parameters ===
        theta = (n_doc_topic + hparams.alpha) / np.sum(n_doc_topic + hparams.alpha, axis=1, keepdims=True)
        phi = (n_topic_word + hparams.beta) / np.sum(n_topic_word + hparams.beta, axis=1, keepdims=True)

        for topic in range(corpus.num_topics):
            top_words = np.argsort(phi[topic])[::-1][:10]
            top_probs = phi[topic, top_words]
            top_words = [corpus.id2word[word] for word in top_words]
            print(f"Topic {topic}:", top_words)
# Out:
# Initializing...
# Gibbs sampling...
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# Iter [0]===
# Topic 0: ['network', 'model', 'learning', 'method', 'algorithm', 'function', 'problem', 'learn', 'university', 'neural']
# Topic 1: ['problem', 'network', 'model', 'datum', 'neural', 'method', 'algorithm', 'learn', 'learning', 'abstract']
# Topic 2: ['model', 'learning', 'network', 'algorithm', 'neural', 'problem', 'system', 'method', 'university', 'function']
# Topic 3: ['model', 'network', 'learning', 'algorithm', 'problem', 'university', 'neural', 'method', 'datum', 'learn']
# Topic 4: ['network', 'model', 'problem', 'datum', 'algorithm', 'introduction', 'university', 'function', 'learning', 'learn']
# Topic 5: ['network', 'model', 'algorithm', 'learning', 'learn', 'neural', 'function', 'datum', 'introduction', 'abstract']
# Topic 6: ['network', 'model', 'datum', 'algorithm', 'learn', 'neural', 'task', 'university', 'learning', 'abstract']
# Topic 7: ['model', 'learning', 'network', 'problem', 'learn', 'university', 'algorithm', 'function', 'edu', 'neural']
# Topic 8: ['model', 'network', 'learning', 'learn', 'datum', 'edu', 'problem', 'neural', 'university', 'algorithm']
# Topic 9: ['model', 'network', 'problem', 'learning', 'learn', 'algorithm', 'state', 'abstract', 'information', 'datum']
# Iter [10]===
# Topic 0: ['datum', 'learn', 'learning', 'set', 'training', 'algorithm', 'example', 'function', 'error', 'network']
# Topic 1: ['learning', 'algorithm', 'learn', 'deep', 'state', 'method', 'model', 'problem', 'com', 'base']
# Topic 2: ['problem', 'university', 'method', 'gradient', 'regret', 'optimization', 'model', 'agent', 'prediction', 'online']
# Topic 3: ['model', 'datum', 'learn', 'problem', 'generative', 'university', 'propose', 'variable', 'distribution', 'approach']
# Topic 4: ['function', 'problem', 'algorithm', 't', 'x', 'university', 'time', 'model', 'optimization', 'kernel']
# Topic 5: ['n', 'k', 'algorithm', 'x', 'matrix', 'e', 'sample', 'method', 'distribution', 'edu']
# Topic 6: ['network', 'neural', 'input', 'unit', 'model', 'neuron', 'memory', 'pattern', 'cell', 'system']
# Topic 7: ['model', 'image', 'object', 'system', 'representation', 'visual', 'learn', 'task', 'information', 'human']
# Topic 8: ['learning', 'task', 'learn', 'problem', 'label', 'distribution', 'datum', 'edu', 'image', 'university']
# Topic 9: ['network', 'neural', 'state', 'system', 'input', 'neuron', 'activity', 'function', 'e', 'j']
# Iter [20]===
# Topic 0: ['learn', 'learning', 'datum', 'training', 'set', 'method', 'algorithm', 'example', 'vector', 'error']
# Topic 1: ['learning', 'state', 'model', 'deep', 'learn', 'com', 'algorithm', 'reinforcement', 'task', 'policy']
# Topic 2: ['problem', 'online', 't', 'prediction', 'regret', 's', 'algorithm', 'setting', 'university', 'model']
# Topic 3: ['model', 'datum', 'learn', 'university', 'distribution', 'inference', 'method', 'generative', 'latent', 'variable']
# Topic 4: ['function', 'problem', 'algorithm', 'optimization', 'method', 'x', 'gradient', 'convex', 'stochastic', 'edu']
# Topic 5: ['n', 'x', 'k', 'matrix', 'sample', 'algorithm', 'e', 'distribution', 'r', 'i']
# Topic 6: ['network', 'neural', 'neuron', 'model', 'unit', 'memory', 'cell', 'pattern', 'input', 'system']
# Topic 7: ['image', 'model', 'object', 'visual', 'system', 'representation', 'recognition', 'task', 'human', 'speech']
# Topic 8: ['learning', 'learn', 'task', 'label', 'datum', 'training', 'deep', 'image', 'distribution', 'university']
# Topic 9: ['network', 'neural', 'input', 'state', 'system', 't', 'weight', 'output', 'function', 'layer']
# Iter [30]===
# Topic 0: ['datum', 'learning', 'learn', 'set', 'training', 'method', 'model', 'problem', 'classification', 'algorithm']
# Topic 1: ['learning', 'state', 'learn', 'model', 'policy', 'reinforcement', 'task', 'deep', 'com', 'algorithm']
# Topic 2: ['algorithm', 'problem', 'online', 'regret', 't', 's', 'prediction', 'setting', 'bandit', 'function']
# Topic 3: ['model', 'datum', 'university', 'inference', 'approach', 'process', 'distribution', 'method', 'learn', 'variable']
# Topic 4: ['problem', 'function', 'algorithm', 'optimization', 'gradient', 'method', 'convex', 'edu', 'stochastic', 'convergence']
# Topic 5: ['x', 'n', 'matrix', 'k', 'sample', 'algorithm', 'i', 'e', 'd', 'p']
# Topic 6: ['network', 'neural', 'neuron', 'model', 'memory', 'cell', 'time', 'system', 'information', 'pattern']
# Topic 7: ['image', 'object', 'model', 'visual', 'system', 'recognition', 'representation', 'human', 'speech', 'feature']
# Topic 8: ['learning', 'datum', 'learn', 'task', 'deep', 'label', 'training', 'image', 'network', 'gan']
# Topic 9: ['network', 'neural', 'input', 'state', 'output', 'system', 'weight', 'learn', 'function', 't']
# Iter [40]===
# Topic 0: ['learn', 'datum', 'learning', 'set', 'training', 'model', 'method', 'task', 'problem', 'classification']
# Topic 1: ['learning', 'state', 'learn', 'model', 'policy', 'reinforcement', 'task', 'deep', 'method', 'com']
# Topic 2: ['problem', 'online', 'algorithm', 't', 'regret', 'prediction', 's', 'new', 'decision', 'bandit']
# Topic 3: ['model', 'datum', 'inference', 'distribution', 'university', 'learn', 'approach', 'method', 'process', 'variable']
# Topic 4: ['algorithm', 'problem', 'function', 'optimization', 'gradient', 'method', 'convex', 'stochastic', 'edu', 'convergence']
# Topic 5: ['x', 'n', 'k', 'matrix', 'sample', 'i', 'p', 'd', 'y', 'e']
# Topic 6: ['neural', 'neuron', 'network', 'model', 'cell', 'memory', 'system', 'activity', 'pattern', 'information']
# Topic 7: ['image', 'object', 'model', 'system', 'visual', 'recognition', 'representation', 'speech', 'human', 'task']
# Topic 8: ['datum', 'learning', 'network', 'deep', 'learn', 'training', 'task', 'image', 'label', 'gan']
# Topic 9: ['network', 'neural', 'input', 'state', 'unit', 'output', 'weight', 'layer', 'learn', 'system']
# Iter [50]===
# Topic 0: ['datum', 'learn', 'learning', 'set', 'training', 'model', 'method', 'classification', 'algorithm', 'feature']
# Topic 1: ['learning', 'state', 'learn', 'model', 'task', 'policy', 'reinforcement', 'system', 'com', 'agent']
# Topic 2: ['problem', 'algorithm', 'online', 't', 'regret', 's', 'setting', 'decision', 'bandit', 'prediction']
# Topic 3: ['model', 'datum', 'inference', 'distribution', 'university', 'variable', 'process', 'approach', 'method', 'algorithm']
# Topic 4: ['algorithm', 'problem', 'function', 'optimization', 'gradient', 'method', 'convex', 'edu', 'stochastic', 'convergence']
# Topic 5: ['x', 'n', 'k', 'matrix', 'p', 'sample', 'i', 'y', 'r', 'e']
# Topic 6: ['neuron', 'neural', 'model', 'network', 'cell', 'memory', 'system', 'activity', 'brain', 'pattern']
# Topic 7: ['image', 'object', 'model', 'system', 'visual', 'recognition', 'representation', 'speech', 'information', 'input']
# Topic 8: ['learning', 'deep', 'network', 'datum', 'image', 'task', 'learn', 'training', 'label', 'propose']
# Topic 9: ['network', 'neural', 'input', 'unit', 'weight', 'output', 'state', 'function', 'learn', 'layer']
# Iter [60]===
# Topic 0: ['datum', 'learn', 'set', 'method', 'learning', 'training', 'problem', 'algorithm', 'classification', 'feature']
# Topic 1: ['learning', 'state', 'learn', 'task', 'policy', 'model', 'reinforcement', 'system', 'com', 'agent']
# Topic 2: ['algorithm', 'problem', 'online', 't', 'regret', 'prediction', 'setting', 's', 'new', 'decision']
# Topic 3: ['model', 'datum', 'distribution', 'inference', 'university', 'process', 'method', 'variable', 'approach', 'learn']
# Topic 4: ['algorithm', 'function', 'problem', 'optimization', 'gradient', 'method', 'convex', 'convergence', 'stochastic', 'edu']
# Topic 5: ['x', 'n', 'k', 'matrix', 'p', 'i', 'y', 'd', 'r', 'e']
# Topic 6: ['neuron', 'neural', 'model', 'cell', 'information', 'network', 'brain', 'activity', 'system', 'memory']
# Topic 7: ['object', 'image', 'system', 'visual', 'model', 'recognition', 'representation', 'speech', 'information', 'input']
# Topic 8: ['deep', 'learning', 'datum', 'learn', 'network', 'image', 'task', 'model', 'training', 'neural']
# Topic 9: ['network', 'neural', 'input', 'unit', 'weight', 'output', 'learn', 'state', 'system', 'layer']
# Iter [70]===
# Topic 0: ['datum', 'learn', 'set', 'learning', 'training', 'algorithm', 'classification', 'problem', 'feature', 'method']
# Topic 1: ['learning', 'state', 'learn', 'task', 'policy', 'reinforcement', 'model', 'system', 'agent', 'control']
# Topic 2: ['problem', 'online', 'algorithm', 't', 'regret', 's', 'bandit', 'prediction', 'decision', 'setting']
# Topic 3: ['model', 'datum', 'distribution', 'inference', 'university', 'variable', 'process', 'approach', 'method', 'algorithm']
# Topic 4: ['algorithm', 'function', 'problem', 'gradient', 'optimization', 'method', 'convex', 'edu', 'stochastic', 'convergence']
# Topic 5: ['x', 'n', 'k', 'matrix', 'p', 'i', 'y', 'e', 'r', 'd']
# Topic 6: ['neuron', 'neural', 'model', 'cell', 'memory', 'activity', 'brain', 'time', 'pattern', 'information']
# Topic 7: ['object', 'model', 'image', 'system', 'visual', 'recognition', 'representation', 'speech', 'information', 'human']
# Topic 8: ['deep', 'network', 'datum', 'learning', 'image', 'learn', 'model', 'task', 'training', 'neural']
# Topic 9: ['network', 'neural', 'input', 'unit', 'weight', 'output', 'learn', 'system', 'state', 'layer']
# Iter [80]===
# Topic 0: ['datum', 'learn', 'set', 'learning', 'algorithm', 'feature', 'training', 'classification', 'method', 'class']
# Topic 1: ['learning', 'learn', 'state', 'policy', 'reinforcement', 'task', 'model', 'system', 'control', 'agent']
# Topic 2: ['algorithm', 'problem', 'online', 't', 'regret', 'learning', 'prediction', 's', 'setting', 'bandit']
# Topic 3: ['model', 'datum', 'distribution', 'university', 'inference', 'method', 'variable', 'process', 'edu', 'approach']
# Topic 4: ['algorithm', 'problem', 'function', 'gradient', 'optimization', 'method', 'convex', 'convergence', 'edu', 'stochastic']
# Topic 5: ['x', 'n', 'matrix', 'k', 'y', 'i', 'p', 't', 'e', 'd']
# Topic 6: ['neuron', 'neural', 'model', 'cell', 'information', 'activity', 'system', 'brain', 'pattern', 'university']
# Topic 7: ['object', 'image', 'visual', 'system', 'model', 'recognition', 'representation', 'speech', 'information', 'human']
# Topic 8: ['deep', 'network', 'learning', 'datum', 'task', 'image', 'model', 'training', 'learn', 'propose']
# Topic 9: ['network', 'neural', 'input', 'unit', 'weight', 'output', 'learn', 'state', 'system', 'layer']
# Iter [90]===
# Topic 0: ['datum', 'learn', 'feature', 'set', 'learning', 'training', 'classification', 'method', 'information', 'example']
# Topic 1: ['learning', 'state', 'learn', 'policy', 'reinforcement', 'system', 'task', 'model', 'agent', 'control']
# Topic 2: ['algorithm', 'problem', 'online', 't', 'regret', 's', 'bandit', 'prediction', 'setting', 'decision']
# Topic 3: ['model', 'datum', 'distribution', 'university', 'inference', 'variable', 'approach', 'gaussian', 'edu', 'process']
# Topic 4: ['algorithm', 'problem', 'gradient', 'optimization', 'function', 'method', 'learning', 'convex', 'edu', 'convergence']
# Topic 5: ['x', 'n', 'matrix', 'k', 'p', 'i', 'y', 'd', 't', 'e']
# Topic 6: ['neuron', 'model', 'neural', 'cell', 'activity', 'brain', 'information', 'system', 'signal', 'university']
# Topic 7: ['object', 'system', 'image', 'visual', 'model', 'recognition', 'speech', 'representation', 'human', 'input']
# Topic 8: ['deep', 'model', 'network', 'datum', 'learning', 'image', 'task', 'learn', 'neural', 'training']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'weight', 'learn', 'function', 'state', 'layer']
# Iter [100]===
# Topic 0: ['datum', 'learn', 'set', 'learning', 'method', 'problem', 'feature', 'training', 'classification', 'example']
# Topic 1: ['learning', 'learn', 'policy', 'state', 'reinforcement', 'task', 'model', 'system', 'control', 'agent']
# Topic 2: ['algorithm', 'problem', 'online', 't', 'regret', 'prediction', 'setting', 'bandit', 'university', 'new']
# Topic 3: ['model', 'datum', 'distribution', 'university', 'inference', 'approach', 'variable', 'edu', 'method', 'process']
# Topic 4: ['algorithm', 'problem', 'function', 'gradient', 'optimization', 'method', 'convex', 'edu', 'convergence', 'stochastic']
# Topic 5: ['x', 'n', 'matrix', 'k', 'p', 'y', 't', 'i', 'function', 'd']
# Topic 6: ['neuron', 'neural', 'model', 'cell', 'activity', 'brain', 'system', 'information', 'time', 'study']
# Topic 7: ['object', 'image', 'system', 'visual', 'model', 'recognition', 'input', 'speech', 'representation', 'human']
# Topic 8: ['deep', 'model', 'learning', 'network', 'datum', 'task', 'learn', 'image', 'neural', 'training']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'weight', 'system', 'learn', 'state', 'layer']
# Iter [110]===
# Topic 0: ['datum', 'learn', 'learning', 'set', 'feature', 'method', 'training', 'classification', 'algorithm', 'example']
# Topic 1: ['learning', 'learn', 'policy', 'state', 'reinforcement', 'system', 'agent', 'algorithm', 'model', 'task']
# Topic 2: ['algorithm', 'problem', 'online', 't', 'regret', 'new', 'bandit', 'setting', 'university', 'learning']
# Topic 3: ['model', 'datum', 'distribution', 'university', 'inference', 'variable', 'process', 'gaussian', 'edu', 'approach']
# Topic 4: ['algorithm', 'problem', 'function', 'optimization', 'gradient', 'method', 'convex', 'edu', 'convergence', 'stochastic']
# Topic 5: ['x', 'n', 'matrix', 'k', 'i', 'y', 'r', 'p', 'd', 't']
# Topic 6: ['neuron', 'model', 'neural', 'cell', 'brain', 'activity', 'university', 'information', 'spike', 'study']
# Topic 7: ['object', 'system', 'image', 'visual', 'model', 'recognition', 'representation', 'speech', 'human', 'information']
# Topic 8: ['deep', 'model', 'task', 'network', 'learning', 'image', 'datum', 'learn', 'neural', 'training']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'weight', 'system', 'function', 'state', 'layer']
# Iter [120]===
# Topic 0: ['datum', 'learn', 'set', 'learning', 'feature', 'algorithm', 'problem', 'training', 'method', 'classification']
# Topic 1: ['learning', 'learn', 'policy', 'state', 'reinforcement', 'system', 'agent', 'task', 'control', 'model']
# Topic 2: ['problem', 'online', 'algorithm', 'regret', 't', 'bandit', 'new', 's', 'good', 'setting']
# Topic 3: ['model', 'datum', 'distribution', 'inference', 'university', 'approach', 'variable', 'process', 'method', 'gaussian']
# Topic 4: ['algorithm', 'problem', 'optimization', 'function', 'gradient', 'method', 'convex', 'learning', 'edu', 'stochastic']
# Topic 5: ['x', 'n', 'matrix', 'k', 'i', 't', 'y', 'd', 'o', 'p']
# Topic 6: ['neuron', 'neural', 'model', 'cell', 'activity', 'brain', 'information', 'time', 'pattern', 'study']
# Topic 7: ['object', 'system', 'image', 'model', 'visual', 'recognition', 'speech', 'information', 'representation', 'input']
# Topic 8: ['deep', 'model', 'network', 'task', 'image', 'learning', 'neural', 'learn', 'datum', 'propose']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'weight', 'system', 'learn', 'function', 'state']
# Iter [130]===
# Topic 0: ['datum', 'learn', 'set', 'learning', 'feature', 'problem', 'algorithm', 'method', 'example', 'classification']
# Topic 1: ['learning', 'learn', 'policy', 'reinforcement', 'state', 'system', 'agent', 'control', 'algorithm', 'model']
# Topic 2: ['problem', 'online', 'algorithm', 't', 'regret', 'prediction', 'bandit', 'new', 'bound', 'setting']
# Topic 3: ['model', 'datum', 'distribution', 'inference', 'university', 'method', 'variable', 'gaussian', 'process', 'approach']
# Topic 4: ['algorithm', 'problem', 'function', 'gradient', 'optimization', 'method', 'convex', 'edu', 'convergence', 'stochastic']
# Topic 5: ['x', 'n', 'k', 'matrix', 'i', 'y', 't', 'e', 'd', 'p']
# Topic 6: ['neuron', 'neural', 'model', 'cell', 'brain', 'activity', 'information', 'university', 'time', 'spike']
# Topic 7: ['object', 'system', 'visual', 'image', 'recognition', 'model', 'speech', 'input', 'human', 'information']
# Topic 8: ['model', 'deep', 'network', 'task', 'learning', 'image', 'learn', 'neural', 'datum', 'propose']
# Topic 9: ['network', 'neural', 'input', 'unit', 'weight', 'output', 'system', 'function', 'learn', 'layer']
# Iter [140]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'set', 'feature', 'classification', 'algorithm', 'example', 'method']
# Topic 1: ['learning', 'learn', 'policy', 'reinforcement', 'state', 'system', 'task', 'agent', 'problem', 'control']
# Topic 2: ['algorithm', 'problem', 'online', 't', 'regret', 'prediction', 'bandit', 'new', 'setting', 'multi']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'variable', 'process', 'gaussian', 'method', 'edu']
# Topic 4: ['algorithm', 'problem', 'optimization', 'function', 'gradient', 'method', 'convex', 'edu', 'stochastic', 'convergence']
# Topic 5: ['x', 'n', 'matrix', 'k', 't', 'y', 'i', 'f', 'p', 'r']
# Topic 6: ['neuron', 'neural', 'model', 'cell', 'brain', 'information', 'activity', 'university', 'signal', 'introduction']
# Topic 7: ['object', 'system', 'visual', 'image', 'recognition', 'model', 'speech', 'input', 'representation', 'information']
# Topic 8: ['model', 'deep', 'network', 'learning', 'image', 'task', 'datum', 'learn', 'neural', 'train']
# Topic 9: ['network', 'neural', 'input', 'unit', 'weight', 'output', 'system', 'learn', 'state', 'layer']
# Iter [150]===
# Topic 0: ['datum', 'learn', 'learning', 'set', 'problem', 'method', 'feature', 'classification', 'label', 'algorithm']
# Topic 1: ['learning', 'learn', 'policy', 'state', 'reinforcement', 'system', 'agent', 'control', 'algorithm', 'task']
# Topic 2: ['problem', 'online', 'algorithm', 'regret', 't', 'bandit', 'setting', 'decision', 'prediction', 'new']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'variable', 'approach', 'algorithm', 'gaussian', 'process']
# Topic 4: ['algorithm', 'problem', 'optimization', 'function', 'gradient', 'method', 'convex', 'edu', 'learning', 'stochastic']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'i', 'y', 'p', 'f', 'd']
# Topic 6: ['neuron', 'model', 'neural', 'cell', 'brain', 'activity', 'information', 'university', 'time', 'spike']
# Topic 7: ['object', 'system', 'visual', 'image', 'model', 'recognition', 'speech', 'input', 'information', 'representation']
# Topic 8: ['deep', 'model', 'network', 'task', 'image', 'learning', 'datum', 'learn', 'neural', 'training']
# Topic 9: ['network', 'neural', 'input', 'unit', 'weight', 'output', 'system', 'layer', 'function', 'state']
# Iter [160]===
# Topic 0: ['datum', 'learn', 'learning', 'set', 'algorithm', 'feature', 'problem', 'label', 'training', 'classification']
# Topic 1: ['learning', 'policy', 'learn', 'reinforcement', 'state', 'system', 'agent', 'control', 'algorithm', 'task']
# Topic 2: ['problem', 'online', 'regret', 't', 'algorithm', 'bandit', 'model', 'new', 'learning', 'decision']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'variable', 'university', 'gaussian', 'process', 'method', 'approach']
# Topic 4: ['algorithm', 'problem', 'gradient', 'optimization', 'function', 'method', 'convex', 'edu', 'stochastic', 'convergence']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'i', 'y', 'p', 'd', 'o']
# Topic 6: ['neuron', 'model', 'neural', 'cell', 'brain', 'activity', 'university', 'information', 'spike', 'signal']
# Topic 7: ['object', 'system', 'visual', 'image', 'model', 'recognition', 'speech', 'information', 'representation', 'input']
# Topic 8: ['deep', 'model', 'network', 'task', 'learning', 'image', 'neural', 'datum', 'learn', 'train']
# Topic 9: ['network', 'neural', 'input', 'unit', 'weight', 'output', 'system', 'function', 'learn', 'state']
# Iter [170]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'set', 'feature', 'algorithm', 'label', 'classification', 'method']
# Topic 1: ['learning', 'policy', 'reinforcement', 'state', 'learn', 'system', 'agent', 'control', 'task', 'algorithm']
# Topic 2: ['algorithm', 'problem', 'online', 'regret', 't', 'learning', 'bandit', 'new', 'prediction', 'bound']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'process', 'variable', 'gaussian', 'approach', 'bayesian']
# Topic 4: ['algorithm', 'problem', 'function', 'optimization', 'gradient', 'method', 'convex', 'stochastic', 'edu', 'university']
# Topic 5: ['x', 'n', 't', 'k', 'matrix', 'y', 'i', 'p', 'd', 'r']
# Topic 6: ['neuron', 'model', 'neural', 'cell', 'brain', 'activity', 'information', 'university', 'study', 'spike']
# Topic 7: ['object', 'system', 'image', 'visual', 'model', 'recognition', 'speech', 'information', 'representation', 'd']
# Topic 8: ['model', 'network', 'deep', 'image', 'task', 'learn', 'neural', 'learning', 'datum', 'train']
# Topic 9: ['network', 'neural', 'input', 'unit', 'weight', 'system', 'output', 'learn', 'function', 'layer']
# Iter [180]===
# Topic 0: ['datum', 'learn', 'learning', 'feature', 'problem', 'set', 'algorithm', 'method', 'label', 'classification']
# Topic 1: ['learning', 'policy', 'learn', 'state', 'reinforcement', 'system', 'agent', 'control', 'algorithm', 'task']
# Topic 2: ['problem', 'online', 'algorithm', 'regret', 't', 's', 'new', 'bandit', 'learning', 'decision']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'process', 'gaussian', 'variable', 'bayesian', 'method']
# Topic 4: ['algorithm', 'problem', 'gradient', 'optimization', 'function', 'method', 'edu', 'convex', 'stochastic', 'convergence']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'i', 'y', 'd', 'o', 'r']
# Topic 6: ['neuron', 'model', 'neural', 'cell', 'brain', 'activity', 'information', 'university', 'spike', 'signal']
# Topic 7: ['object', 'system', 'recognition', 'image', 'visual', 'model', 'speech', 'information', 'representation', 'd']
# Topic 8: ['model', 'network', 'deep', 'image', 'task', 'neural', 'learning', 'learn', 'datum', 'train']
# Topic 9: ['network', 'neural', 'input', 'unit', 'weight', 'output', 'system', 'learn', 'training', 'function']
# Iter [190]===
# Topic 0: ['datum', 'learn', 'problem', 'learning', 'set', 'algorithm', 'feature', 'label', 'method', 'classification']
# Topic 1: ['learning', 'policy', 'learn', 'reinforcement', 'state', 'system', 'control', 'agent', 'model', 'dynamic']
# Topic 2: ['problem', 'algorithm', 'online', 'regret', 't', 'bandit', 'prediction', 'setting', 'decision', 's']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'variable', 'gaussian', 'process', 'approach', 'method']
# Topic 4: ['algorithm', 'problem', 'function', 'gradient', 'optimization', 'method', 'convex', 'edu', 'stochastic', 'university']
# Topic 5: ['x', 'n', 'k', 'matrix', 'i', 't', 'p', 'y', 'o', 'd']
# Topic 6: ['neuron', 'model', 'neural', 'cell', 'brain', 'activity', 'information', 'university', 'spike', 'signal']
# Topic 7: ['object', 'system', 'image', 'visual', 'recognition', 'model', 'speech', 'information', 'representation', 'input']
# Topic 8: ['model', 'deep', 'network', 'task', 'learning', 'learn', 'image', 'neural', 'datum', 'training']
# Topic 9: ['network', 'neural', 'input', 'unit', 'weight', 'system', 'output', 'function', 'learn', 'training']
# Iter [200]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'feature', 'set', 'algorithm', 'label', 'classification', 'task']
# Topic 1: ['learning', 'policy', 'learn', 'state', 'reinforcement', 'system', 'agent', 'control', 'model', 'task']
# Topic 2: ['algorithm', 'problem', 'online', 'regret', 't', 'prediction', 'bandit', 'new', 'university', 's']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'algorithm', 'variable', 'approach', 'gaussian', 'process']
# Topic 4: ['algorithm', 'problem', 'gradient', 'optimization', 'function', 'method', 'convex', 'edu', 'stochastic', 'learning']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'i', 'p', 'y', 'd', 'o']
# Topic 6: ['neuron', 'model', 'neural', 'cell', 'brain', 'activity', 'information', 'university', 'spike', 'e']
# Topic 7: ['object', 'system', 'image', 'visual', 'recognition', 'model', 'speech', 'information', 'representation', 'human']
# Topic 8: ['model', 'network', 'deep', 'learning', 'neural', 'image', 'task', 'learn', 'datum', 'training']
# Topic 9: ['network', 'neural', 'input', 'unit', 'weight', 'output', 'system', 'learn', 'function', 'state']
# Iter [210]===
# Topic 0: ['datum', 'learn', 'learning', 'feature', 'problem', 'set', 'label', 'method', 'classification', 'task']
# Topic 1: ['learning', 'policy', 'learn', 'reinforcement', 'state', 'system', 'agent', 'control', 'algorithm', 'task']
# Topic 2: ['problem', 'algorithm', 'online', 'regret', 't', 'bandit', 's', 'prediction', 'setting', 'learning']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'variable', 'process', 'gaussian', 'approach', 'bayesian']
# Topic 4: ['algorithm', 'problem', 'optimization', 'gradient', 'function', 'method', 'edu', 'convex', 'learning', 'stochastic']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'i', 'y', 'd', 'o', 'r']
# Topic 6: ['neuron', 'model', 'neural', 'cell', 'brain', 'activity', 'information', 'study', 'university', 'signal']
# Topic 7: ['object', 'system', 'visual', 'image', 'recognition', 'model', 'speech', 'representation', 'input', 'human']
# Topic 8: ['network', 'deep', 'model', 'image', 'task', 'learning', 'neural', 'learn', 'datum', 'train']
# Topic 9: ['network', 'neural', 'input', 'unit', 'weight', 'output', 'learn', 'function', 'system', 'state']
# Iter [220]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'algorithm', 'set', 'feature', 'label', 'classification', 'task']
# Topic 1: ['learning', 'learn', 'policy', 'reinforcement', 'state', 'agent', 'system', 'control', 'task', 'environment']
# Topic 2: ['problem', 'online', 'algorithm', 'regret', 't', 'bandit', 'setting', 'new', 'prediction', 's']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'variable', 'gaussian', 'process', 'university', 'approach', 'bayesian']
# Topic 4: ['algorithm', 'problem', 'optimization', 'function', 'gradient', 'method', 'edu', 'convex', 'learning', 'stochastic']
# Topic 5: ['x', 'n', 'k', 'matrix', 'i', 't', 'y', 'r', 'd', 'p']
# Topic 6: ['neuron', 'model', 'neural', 'cell', 'brain', 'activity', 'information', 'university', 'signal', 'spike']
# Topic 7: ['object', 'system', 'visual', 'image', 'recognition', 'model', 'speech', 'information', 'input', 'representation']
# Topic 8: ['deep', 'network', 'model', 'image', 'task', 'learning', 'neural', 'datum', 'learn', 'train']
# Topic 9: ['network', 'neural', 'input', 'unit', 'weight', 'system', 'output', 'function', 'layer', 'learn']
# Iter [230]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'label', 'algorithm', 'set', 'feature', 'classification', 'task']
# Topic 1: ['learning', 'policy', 'learn', 'reinforcement', 'state', 'system', 'control', 'agent', 'algorithm', 'task']
# Topic 2: ['algorithm', 'problem', 'online', 'regret', 't', 's', 'learning', 'prediction', 'bandit', 'new']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'variable', 'university', 'gaussian', 'approach', 'process', 'bayesian']
# Topic 4: ['algorithm', 'problem', 'optimization', 'gradient', 'function', 'method', 'convex', 'edu', 'stochastic', 'learning']
# Topic 5: ['x', 'n', 'matrix', 'k', 't', 'y', 'i', 'o', 'd', 'p']
# Topic 6: ['neuron', 'neural', 'cell', 'model', 'brain', 'activity', 'university', 'information', 'study', 'spike']
# Topic 7: ['object', 'system', 'image', 'visual', 'recognition', 'model', 'speech', 'information', 'representation', 'input']
# Topic 8: ['model', 'deep', 'network', 'task', 'image', 'learning', 'neural', 'learn', 'datum', 'training']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'weight', 'system', 'learn', 'function', 'training']
# Iter [240]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'algorithm', 'set', 'label', 'method', 'feature', 'classification']
# Topic 1: ['learning', 'policy', 'learn', 'reinforcement', 'state', 'agent', 'control', 'system', 'task', 'algorithm']
# Topic 2: ['online', 'problem', 'algorithm', 'regret', 't', 'prediction', 'bandit', 'bound', 'new', 'set']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'variable', 'university', 'gaussian', 'process', 'approach', 'algorithm']
# Topic 4: ['algorithm', 'problem', 'function', 'optimization', 'gradient', 'method', 'edu', 'convex', 'stochastic', 'convergence']
# Topic 5: ['x', 'n', 'matrix', 'k', 't', 'i', 'y', 'p', 'o', 'e']
# Topic 6: ['neuron', 'model', 'neural', 'cell', 'brain', 'activity', 'university', 'information', 'study', 'spike']
# Topic 7: ['object', 'system', 'visual', 'image', 'recognition', 'model', 'speech', 'input', 'representation', 'information']
# Topic 8: ['deep', 'model', 'network', 'image', 'learning', 'task', 'neural', 'learn', 'datum', 'train']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'weight', 'system', 'learn', 'state', 'layer']
# Iter [250]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'method', 'feature', 'algorithm', 'task', 'label', 'set']
# Topic 1: ['learning', 'policy', 'learn', 'reinforcement', 'state', 'system', 'control', 'agent', 'task', 'dynamic']
# Topic 2: ['online', 'problem', 'algorithm', 't', 'regret', 'bandit', 'new', 's', 'learning', 'prediction']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'variable', 'gaussian', 'approach', 'process', 'algorithm']
# Topic 4: ['algorithm', 'problem', 'function', 'optimization', 'gradient', 'method', 'edu', 'convex', 'learning', 'stochastic']
# Topic 5: ['x', 'n', 'matrix', 'k', 't', 'y', 'p', 'i', 'o', 'r']
# Topic 6: ['neuron', 'model', 'neural', 'cell', 'brain', 'activity', 'information', 'signal', 'university', 'spike']
# Topic 7: ['object', 'system', 'image', 'visual', 'recognition', 'model', 'speech', 'input', 'representation', 'information']
# Topic 8: ['network', 'deep', 'model', 'neural', 'image', 'learning', 'task', 'learn', 'train', 'datum']
# Topic 9: ['network', 'neural', 'input', 'unit', 'weight', 'output', 'system', 'function', 'state', 'error']
# Iter [260]===
# Topic 0: ['datum', 'learn', 'learning', 'feature', 'task', 'problem', 'set', 'algorithm', 'method', 'label']
# Topic 1: ['learning', 'policy', 'learn', 'reinforcement', 'state', 'agent', 'control', 'system', 'task', 'algorithm']
# Topic 2: ['problem', 'algorithm', 'online', 'regret', 't', 'bandit', 'model', 's', 'new', 'multi']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'variable', 'process', 'approach', 'gaussian', 'algorithm']
# Topic 4: ['algorithm', 'problem', 'function', 'optimization', 'gradient', 'method', 'edu', 'convex', 'stochastic', 'learning']
# Topic 5: ['x', 'n', 'matrix', 'k', 't', 'y', 'i', 'o', 'p', 'd']
# Topic 6: ['neuron', 'model', 'cell', 'neural', 'activity', 'information', 'brain', 'university', 'spike', 'signal']
# Topic 7: ['system', 'object', 'image', 'visual', 'model', 'recognition', 'speech', 'representation', 'information', 'input']
# Topic 8: ['network', 'deep', 'model', 'image', 'neural', 'learning', 'task', 'learn', 'datum', 'train']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'weight', 'function', 'system', 'learn', 'state']
# Iter [270]===
# Topic 0: ['datum', 'learn', 'problem', 'learning', 'feature', 'set', 'task', 'label', 'method', 'algorithm']
# Topic 1: ['learning', 'policy', 'learn', 'reinforcement', 'state', 'system', 'agent', 'control', 'problem', 'dynamic']
# Topic 2: ['algorithm', 'online', 't', 'regret', 'problem', 's', 'bandit', 'model', 'prediction', 'bound']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'variable', 'approach', 'process', 'gaussian', 'university', 'method']
# Topic 4: ['algorithm', 'problem', 'function', 'optimization', 'gradient', 'method', 'edu', 'convex', 'learning', 'stochastic']
# Topic 5: ['x', 'n', 'matrix', 'k', 't', 'y', 'i', 'd', 'r', 'p']
# Topic 6: ['neuron', 'model', 'neural', 'cell', 'brain', 'information', 'activity', 'university', 'spike', 'signal']
# Topic 7: ['object', 'system', 'image', 'visual', 'recognition', 'model', 'speech', 'information', 'input', 'representation']
# Topic 8: ['network', 'deep', 'model', 'image', 'neural', 'task', 'learning', 'learn', 'train', 'representation']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'weight', 'system', 'learn', 'function', 'state']
# Iter [280]===
# Topic 0: ['datum', 'learn', 'learning', 'task', 'feature', 'problem', 'method', 'set', 'label', 'algorithm']
# Topic 1: ['learning', 'policy', 'learn', 'reinforcement', 'state', 'control', 'agent', 'system', 'task', 'algorithm']
# Topic 2: ['problem', 'algorithm', 'online', 'regret', 't', 's', 'bandit', 'prediction', 'new', 'learning']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'process', 'university', 'variable', 'gaussian', 'method', 'bayesian']
# Topic 4: ['algorithm', 'problem', 'function', 'optimization', 'gradient', 'method', 'edu', 'convex', 'stochastic', 'learning']
# Topic 5: ['x', 'n', 'k', 'matrix', 'y', 't', 'i', 'r', 'd', 'o']
# Topic 6: ['neuron', 'model', 'cell', 'neural', 'activity', 'brain', 'information', 'university', 'spike', 'signal']
# Topic 7: ['system', 'object', 'image', 'visual', 'recognition', 'model', 'speech', 'input', 'information', 'representation']
# Topic 8: ['network', 'deep', 'model', 'neural', 'image', 'learning', 'learn', 'task', 'train', 'training']
# Topic 9: ['network', 'neural', 'input', 'unit', 'system', 'output', 'weight', 'function', 'learn', 'training']
# Iter [290]===
# Topic 0: ['datum', 'learn', 'problem', 'learning', 'task', 'feature', 'algorithm', 'label', 'method', 'set']
# Topic 1: ['learning', 'policy', 'learn', 'reinforcement', 'state', 'system', 'control', 'agent', 'task', 'environment']
# Topic 2: ['algorithm', 'problem', 'online', 'regret', 't', 's', 'prediction', 'bandit', 'new', 'learning']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'process', 'variable', 'gaussian', 'method', 'approach']
# Topic 4: ['algorithm', 'problem', 'function', 'optimization', 'gradient', 'method', 'edu', 'convex', 'stochastic', 'university']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'i', 'y', 'r', 'f', 'e']
# Topic 6: ['neuron', 'model', 'cell', 'neural', 'activity', 'brain', 'information', 'university', 'signal', 'spike']
# Topic 7: ['system', 'object', 'image', 'visual', 'recognition', 'model', 'speech', 'input', 'information', 'representation']
# Topic 8: ['deep', 'network', 'model', 'learning', 'neural', 'image', 'task', 'learn', 'train', 'datum']
# Topic 9: ['network', 'neural', 'input', 'unit', 'weight', 'output', 'learn', 'system', 'training', 'function']
# Iter [300]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'feature', 'method', 'task', 'label', 'set', 'algorithm']
# Topic 1: ['learning', 'policy', 'learn', 'reinforcement', 'state', 'system', 'agent', 'control', 'task', 'algorithm']
# Topic 2: ['problem', 'algorithm', 'online', 'regret', 't', 'prediction', 'bandit', 'new', 's', 'decision']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'variable', 'process', 'gaussian', 'bayesian', 'approach']
# Topic 4: ['algorithm', 'problem', 'function', 'optimization', 'gradient', 'method', 'convex', 'edu', 'stochastic', 'learning']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'y', 'p', 'i', 'o', 'e']
# Topic 6: ['neuron', 'model', 'cell', 'neural', 'brain', 'activity', 'information', 'university', 'response', 'spike']
# Topic 7: ['object', 'system', 'image', 'visual', 'recognition', 'model', 'speech', 'information', 'input', 'representation']
# Topic 8: ['model', 'deep', 'network', 'image', 'neural', 'learning', 'task', 'learn', 'train', 'training']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'weight', 'learn', 'system', 'state', 'training']
# Iter [310]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'feature', 'task', 'algorithm', 'set', 'label', 'method']
# Topic 1: ['learning', 'learn', 'policy', 'reinforcement', 'state', 'agent', 'system', 'control', 'task', 'environment']
# Topic 2: ['algorithm', 'problem', 'online', 'regret', 't', 'model', 'bandit', 'new', 'prediction', 'learning']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'approach', 'variable', 'process', 'university', 'gaussian', 'bayesian']
# Topic 4: ['algorithm', 'problem', 'function', 'gradient', 'optimization', 'method', 'edu', 'convex', 'stochastic', 'convergence']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'i', 'p', 'y', 'o', 'r']
# Topic 6: ['neuron', 'model', 'cell', 'neural', 'brain', 'activity', 'information', 'university', 'spike', 'study']
# Topic 7: ['object', 'system', 'image', 'visual', 'model', 'recognition', 'speech', 'information', 'representation', 'input']
# Topic 8: ['network', 'deep', 'model', 'image', 'neural', 'learning', 'task', 'learn', 'train', 'datum']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'weight', 'system', 'learn', 'function', 'training']
# Iter [320]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'task', 'set', 'feature', 'algorithm', 'method', 'label']
# Topic 1: ['learning', 'policy', 'learn', 'reinforcement', 'state', 'agent', 'control', 'system', 'game', 'task']
# Topic 2: ['online', 'regret', 't', 'algorithm', 'problem', 'prediction', 'bandit', 's', 'new', 'learning']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'variable', 'process', 'gaussian', 'approach', 'bayesian']
# Topic 4: ['algorithm', 'problem', 'optimization', 'function', 'gradient', 'method', 'edu', 'convex', 'stochastic', 'learning']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'y', 'p', 'e', 'i', 'o']
# Topic 6: ['neuron', 'model', 'cell', 'neural', 'brain', 'information', 'activity', 'university', 'spike', 'response']
# Topic 7: ['object', 'image', 'system', 'visual', 'recognition', 'model', 'speech', 'information', 'input', 'representation']
# Topic 8: ['network', 'deep', 'model', 'learning', 'neural', 'image', 'task', 'learn', 'datum', 'train']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'weight', 'system', 'learn', 'function', 'training']
# Iter [330]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'task', 'algorithm', 'feature', 'set', 'label', 'method']
# Topic 1: ['learning', 'policy', 'learn', 'reinforcement', 'state', 'system', 'agent', 'control', 'task', 'algorithm']
# Topic 2: ['algorithm', 'online', 'problem', 'regret', 't', 'new', 'prediction', 'bandit', 'setting', 's']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'variable', 'gaussian', 'approach', 'process', 'method']
# Topic 4: ['algorithm', 'problem', 'function', 'optimization', 'gradient', 'method', 'convex', 'edu', 'learning', 'stochastic']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'y', 'i', 'r', 'p', 'd']
# Topic 6: ['neuron', 'model', 'cell', 'neural', 'brain', 'activity', 'information', 'university', 'spike', 'study']
# Topic 7: ['object', 'system', 'image', 'visual', 'recognition', 'model', 'speech', 'information', 'input', 'representation']
# Topic 8: ['deep', 'network', 'model', 'image', 'neural', 'learning', 'learn', 'task', 'train', 'training']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'weight', 'system', 'function', 'learn', 'state']
# Iter [340]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'task', 'set', 'feature', 'label', 'method', 'algorithm']
# Topic 1: ['learning', 'learn', 'policy', 'reinforcement', 'state', 'system', 'agent', 'control', 'task', 'dynamic']
# Topic 2: ['algorithm', 'problem', 'online', 'regret', 't', 's', 'model', 'bandit', 'prediction', 'new']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'variable', 'university', 'gaussian', 'process', 'estimate', 'bayesian']
# Topic 4: ['algorithm', 'problem', 'function', 'optimization', 'gradient', 'method', 'convex', 'edu', 'stochastic', 'learning']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'i', 'y', 'e', 'o', 'r']
# Topic 6: ['neuron', 'model', 'cell', 'neural', 'brain', 'activity', 'university', 'information', 'spike', 'response']
# Topic 7: ['object', 'system', 'image', 'visual', 'recognition', 'model', 'speech', 'information', 'representation', 'problem']
# Topic 8: ['deep', 'network', 'model', 'neural', 'image', 'learning', 'task', 'learn', 'train', 'datum']
# Topic 9: ['network', 'neural', 'input', 'unit', 'weight', 'output', 'learn', 'training', 'state', 'system']
# Iter [350]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'task', 'algorithm', 'label', 'set', 'feature', 'method']
# Topic 1: ['learning', 'learn', 'policy', 'reinforcement', 'state', 'system', 'control', 'agent', 'dynamic', 'model']
# Topic 2: ['problem', 'algorithm', 'online', 'regret', 't', 's', 'bandit', 'new', 'learning', 'setting']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'variable', 'university', 'process', 'gaussian', 'bayesian', 'method']
# Topic 4: ['algorithm', 'problem', 'function', 'gradient', 'optimization', 'method', 'edu', 'convex', 'stochastic', 'learning']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'y', 'i', 'd', 'e', 'o']
# Topic 6: ['neuron', 'model', 'cell', 'neural', 'brain', 'activity', 'university', 'information', 'study', 'spike']
# Topic 7: ['object', 'system', 'image', 'visual', 'recognition', 'model', 'speech', 'input', 'information', 'representation']
# Topic 8: ['network', 'model', 'deep', 'neural', 'image', 'task', 'learning', 'learn', 'train', 'representation']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'weight', 'learn', 'system', 'function', 'training']
# Iter [360]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'method', 'task', 'algorithm', 'set', 'feature', 'label']
# Topic 1: ['learning', 'learn', 'policy', 'reinforcement', 'state', 'system', 'agent', 'control', 'dynamic', 'task']
# Topic 2: ['algorithm', 'problem', 'online', 'regret', 't', 'bandit', 'university', 's', 'new', 'bound']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'variable', 'process', 'gaussian', 'approach', 'bayesian']
# Topic 4: ['algorithm', 'function', 'problem', 'gradient', 'optimization', 'method', 'convex', 'edu', 'stochastic', 'convergence']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'y', 'i', 'd', 'o', 'r']
# Topic 6: ['neuron', 'model', 'cell', 'neural', 'brain', 'activity', 'university', 'information', 'spike', 'signal']
# Topic 7: ['object', 'system', 'image', 'visual', 'recognition', 'model', 'speech', 'information', 'd', 'input']
# Topic 8: ['network', 'model', 'deep', 'neural', 'image', 'task', 'learning', 'learn', 'train', 'datum']
# Topic 9: ['network', 'neural', 'input', 'output', 'unit', 'weight', 'function', 'system', 'learn', 'training']
# Iter [370]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'task', 'method', 'set', 'feature', 'label', 'algorithm']
# Topic 1: ['learning', 'policy', 'learn', 'reinforcement', 'state', 'agent', 'control', 'system', 'dynamic', 'environment']
# Topic 2: ['algorithm', 'online', 'problem', 'regret', 't', 's', 'bandit', 'prediction', 'bound', 'university']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'approach', 'variable', 'university', 'process', 'gaussian', 'bayesian']
# Topic 4: ['algorithm', 'problem', 'function', 'gradient', 'optimization', 'method', 'convex', 'edu', 'learning', 'stochastic']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'y', 'i', 'e', 'p', 'r']
# Topic 6: ['neuron', 'model', 'neural', 'cell', 'activity', 'brain', 'information', 'university', 'spike', 'study']
# Topic 7: ['system', 'object', 'image', 'visual', 'recognition', 'model', 'speech', 'information', 'input', 'representation']
# Topic 8: ['network', 'model', 'deep', 'image', 'neural', 'learning', 'task', 'learn', 'train', 'training']
# Topic 9: ['network', 'neural', 'input', 'unit', 'weight', 'output', 'system', 'function', 'state', 'training']
# Iter [380]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'task', 'set', 'algorithm', 'feature', 'method', 'label']
# Topic 1: ['learning', 'policy', 'learn', 'reinforcement', 'state', 'control', 'system', 'agent', 'algorithm', 'model']
# Topic 2: ['problem', 'algorithm', 'online', 'regret', 't', 'prediction', 'bandit', 's', 'bound', 'new']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'variable', 'process', 'gaussian', 'university', 'approach', 'sample']
# Topic 4: ['algorithm', 'problem', 'function', 'optimization', 'gradient', 'method', 'edu', 'convex', 'stochastic', 'convergence']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'i', 'y', 'd', 'o', 'p']
# Topic 6: ['neuron', 'model', 'neural', 'cell', 'brain', 'activity', 'information', 'university', 'spike', 'study']
# Topic 7: ['object', 'system', 'image', 'visual', 'model', 'recognition', 'speech', 'representation', 'information', 'human']
# Topic 8: ['network', 'deep', 'model', 'neural', 'image', 'learning', 'task', 'train', 'learn', 'datum']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'weight', 'system', 'learn', 'function', 'training']
# Iter [390]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'task', 'algorithm', 'set', 'feature', 'label', 'method']
# Topic 1: ['learning', 'policy', 'reinforcement', 'learn', 'state', 'control', 'system', 'agent', 'dynamic', 'problem']
# Topic 2: ['algorithm', 'problem', 'online', 'regret', 't', 'bandit', 'prediction', 'bound', 'university', 's']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'gaussian', 'variable', 'process', 'approach', 'method']
# Topic 4: ['algorithm', 'function', 'problem', 'optimization', 'gradient', 'method', 'edu', 'convex', 'convergence', 'stochastic']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'y', 'i', 'p', 'r', 'o']
# Topic 6: ['neuron', 'model', 'cell', 'neural', 'brain', 'activity', 'information', 'university', 'study', 'spike']
# Topic 7: ['object', 'image', 'system', 'visual', 'recognition', 'model', 'speech', 'representation', 'information', 'input']
# Topic 8: ['network', 'deep', 'model', 'neural', 'image', 'learning', 'task', 'train', 'learn', 'datum']
# Topic 9: ['network', 'neural', 'input', 'output', 'unit', 'weight', 'function', 'learn', 'system', 'training']
# Iter [400]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'task', 'algorithm', 'set', 'feature', 'label', 'method']
# Topic 1: ['learning', 'policy', 'learn', 'reinforcement', 'state', 'system', 'control', 'agent', 'model', 'dynamic']
# Topic 2: ['problem', 'online', 'algorithm', 'regret', 't', 'new', 'prediction', 's', 'bandit', 'bound']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'variable', 'process', 'gaussian', 'approach', 'bayesian']
# Topic 4: ['algorithm', 'function', 'problem', 'optimization', 'gradient', 'method', 'edu', 'convex', 'convergence', 'stochastic']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'y', 'i', 'd', 'p', 'e']
# Topic 6: ['neuron', 'model', 'cell', 'brain', 'neural', 'activity', 'information', 'university', 'study', 'spike']
# Topic 7: ['object', 'system', 'image', 'visual', 'recognition', 'model', 'speech', 'input', 'information', 'representation']
# Topic 8: ['deep', 'network', 'model', 'neural', 'image', 'learning', 'task', 'learn', 'train', 'representation']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'weight', 'system', 'learn', 'function', 'state']
# Iter [410]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'task', 'method', 'algorithm', 'label', 'set', 'feature']
# Topic 1: ['learning', 'policy', 'learn', 'reinforcement', 'state', 'system', 'control', 'agent', 'model', 'environment']
# Topic 2: ['online', 'problem', 'algorithm', 'regret', 't', 'bandit', 'model', 's', 'prediction', 'learning']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'variable', 'process', 'gaussian', 'university', 'approach', 'bayesian']
# Topic 4: ['algorithm', 'function', 'problem', 'optimization', 'gradient', 'method', 'edu', 'convex', 'stochastic', 'convergence']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'y', 'i', 'p', 'r', 'd']
# Topic 6: ['neuron', 'model', 'neural', 'cell', 'brain', 'activity', 'information', 'study', 'university', 'spike']
# Topic 7: ['object', 'image', 'system', 'visual', 'model', 'recognition', 'speech', 'information', 'input', 'problem']
# Topic 8: ['network', 'deep', 'model', 'neural', 'image', 'learning', 'datum', 'task', 'learn', 'training']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'system', 'weight', 'learn', 'function', 'abstract']
# Iter [420]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'method', 'task', 'algorithm', 'set', 'label', 'feature']
# Topic 1: ['learning', 'policy', 'reinforcement', 'learn', 'state', 'system', 'agent', 'control', 'dynamic', 'environment']
# Topic 2: ['algorithm', 'problem', 'online', 'regret', 't', 'bandit', 's', 'setting', 'model', 'new']
# ...
# Topic 9: ['network', 'neural', 'input', 'unit', 'weight', 'output', 'learn', 'system', 'state', 'training']
# Iter [860]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'algorithm', 'task', 'feature', 'method', 'label', 'classification']
# Topic 1: ['learning', 'learn', 'policy', 'reinforcement', 'state', 'control', 'agent', 'system', 'dynamic', 'model']
# Topic 2: ['problem', 'online', 'algorithm', 'regret', 't', 'bandit', 's', 'bound', 'university', 'prediction']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'variable', 'gaussian', 'process', 'approach', 'bayesian']
# Topic 4: ['algorithm', 'problem', 'function', 'optimization', 'gradient', 'method', 'convex', 'edu', 'stochastic', 'convergence']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'y', 'i', 'p', 'o', 'r']
# Topic 6: ['neuron', 'model', 'cell', 'neural', 'brain', 'information', 'activity', 'university', 'spike', 'signal']
# Topic 7: ['object', 'system', 'image', 'visual', 'recognition', 'model', 'speech', 'information', 'input', 'representation']
# Topic 8: ['model', 'deep', 'network', 'neural', 'image', 'learning', 'learn', 'task', 'representation', 'training']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'weight', 'learn', 'state', 'system', 'e']
# Iter [870]===
# Topic 0: ['datum', 'learn', 'learning', 'task', 'problem', 'algorithm', 'set', 'label', 'method', 'feature']
# Topic 1: ['learning', 'policy', 'learn', 'reinforcement', 'state', 'agent', 'control', 'system', 'model', 'algorithm']
# Topic 2: ['online', 'algorithm', 'problem', 'regret', 't', 'prediction', 'bandit', 's', 'new', 'model']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'variable', 'process', 'gaussian', 'approach', 'bayesian']
# Topic 4: ['algorithm', 'problem', 'function', 'optimization', 'gradient', 'method', 'convex', 'edu', 'learning', 'stochastic']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'y', 'p', 'i', 'o', 'd']
# Topic 6: ['neuron', 'model', 'cell', 'neural', 'brain', 'activity', 'information', 'university', 'study', 'spike']
# Topic 7: ['object', 'system', 'image', 'visual', 'recognition', 'model', 'speech', 'input', 'information', 'problem']
# Topic 8: ['network', 'model', 'deep', 'neural', 'image', 'learning', 'learn', 'representation', 'task', 'train']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'weight', 'function', 'learn', 'training', 'system']
# Iter [880]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'task', 'algorithm', 'method', 'feature', 'set', 'label']
# Topic 1: ['learning', 'policy', 'learn', 'reinforcement', 'state', 'system', 'control', 'agent', 'dynamic', 'model']
# Topic 2: ['problem', 'algorithm', 'online', 'regret', 't', 'prediction', 'bandit', 's', 'multi', 'decision']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'variable', 'process', 'gaussian', 'method', 'algorithm']
# Topic 4: ['algorithm', 'problem', 'function', 'gradient', 'optimization', 'method', 'convex', 'edu', 'stochastic', 'convergence']
# Topic 5: ['x', 'n', 'k', 'matrix', 'y', 't', 'i', 'p', 'o', 'r']
# Topic 6: ['neuron', 'model', 'neural', 'cell', 'brain', 'information', 'activity', 'university', 'spike', 'study']
# Topic 7: ['object', 'system', 'image', 'visual', 'recognition', 'model', 'speech', 'input', 'information', 'base']
# Topic 8: ['network', 'deep', 'model', 'neural', 'image', 'learning', 'learn', 'task', 'train', 'training']
# Topic 9: ['network', 'neural', 'input', 'unit', 'weight', 'output', 'learn', 'system', 'function', 'training']
# Iter [890]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'task', 'algorithm', 'method', 'feature', 'approach', 'set']
# Topic 1: ['learning', 'learn', 'policy', 'reinforcement', 'state', 'system', 'agent', 'control', 'dynamic', 'model']
# Topic 2: ['problem', 'algorithm', 'online', 't', 'regret', 'prediction', 'bandit', 's', 'new', 'learning']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'variable', 'gaussian', 'approach', 'process', 'bayesian']
# Topic 4: ['algorithm', 'problem', 'function', 'gradient', 'optimization', 'method', 'convex', 'edu', 'stochastic', 'convergence']
# Topic 5: ['x', 'n', 'matrix', 'k', 'y', 't', 'i', 'p', 'r', 'o']
# Topic 6: ['neuron', 'model', 'cell', 'neural', 'brain', 'activity', 'information', 'university', 'spike', 'response']
# Topic 7: ['object', 'system', 'visual', 'image', 'recognition', 'model', 'speech', 'information', 'input', 'representation']
# Topic 8: ['network', 'deep', 'model', 'neural', 'image', 'learning', 'task', 'learn', 'training', 'train']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'weight', 'function', 'system', 'training', 'state']
# Iter [900]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'algorithm', 'task', 'method', 'feature', 'set', 'label']
# Topic 1: ['learning', 'policy', 'learn', 'reinforcement', 'state', 'control', 'agent', 'system', 'game', 'dynamic']
# Topic 2: ['problem', 'online', 'algorithm', 'regret', 't', 'bandit', 'prediction', 's', 'new', 'multi']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'variable', 'process', 'gaussian', 'bayesian', 'parameter']
# Topic 4: ['algorithm', 'problem', 'function', 'optimization', 'gradient', 'method', 'convex', 'edu', 'stochastic', 'convergence']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'y', 'i', 'p', 'o', 'r']
# Topic 6: ['neuron', 'neural', 'model', 'cell', 'brain', 'activity', 'university', 'information', 'spike', 'signal']
# Topic 7: ['system', 'object', 'model', 'visual', 'image', 'recognition', 'speech', 'information', 'input', 'representation']
# Topic 8: ['network', 'model', 'deep', 'neural', 'image', 'task', 'learning', 'train', 'learn', 'training']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'weight', 'system', 'training', 'learn', 'error']
# Iter [910]===
# Topic 0: ['datum', 'learning', 'learn', 'problem', 'task', 'algorithm', 'method', 'feature', 'set', 'approach']
# Topic 1: ['learning', 'policy', 'reinforcement', 'learn', 'state', 'control', 'system', 'agent', 'algorithm', 'dynamic']
# Topic 2: ['online', 'problem', 'algorithm', 'regret', 't', 'prediction', 'bandit', 'new', 'model', 'decision']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'variable', 'approach', 'gaussian', 'process', 'parameter']
# Topic 4: ['algorithm', 'problem', 'function', 'optimization', 'gradient', 'method', 'convex', 'edu', 'stochastic', 'learning']
# Topic 5: ['x', 'n', 'matrix', 'k', 't', 'y', 'i', 'o', 'p', 'd']
# Topic 6: ['neuron', 'model', 'neural', 'cell', 'brain', 'activity', 'information', 'university', 'study', 'spike']
# Topic 7: ['object', 'system', 'visual', 'recognition', 'image', 'model', 'speech', 'input', 'information', 'representation']
# Topic 8: ['network', 'deep', 'model', 'image', 'neural', 'learn', 'task', 'learning', 'train', 'training']
# Topic 9: ['network', 'neural', 'input', 'output', 'unit', 'weight', 'learn', 'system', 'training', 'function']
# Iter [920]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'task', 'algorithm', 'method', 'set', 'feature', 'approach']
# Topic 1: ['learning', 'policy', 'reinforcement', 'state', 'learn', 'agent', 'control', 'system', 'dynamic', 'algorithm']
# Topic 2: ['problem', 'algorithm', 'online', 'regret', 't', 'prediction', 'bandit', 'decision', 'model', 'bound']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'variable', 'process', 'gaussian', 'bayesian', 'approach']
# Topic 4: ['algorithm', 'problem', 'function', 'gradient', 'optimization', 'method', 'convex', 'stochastic', 'edu', 'convergence']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'i', 'y', 'p', 'o', 'r']
# Topic 6: ['neuron', 'model', 'cell', 'neural', 'brain', 'activity', 'information', 'university', 'study', 'spike']
# Topic 7: ['object', 'system', 'visual', 'image', 'recognition', 'model', 'speech', 'information', 'input', 'd']
# Topic 8: ['network', 'model', 'deep', 'image', 'neural', 'learning', 'task', 'learn', 'train', 'training']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'training', 'system', 'learn', 'weight', 'function']
# Iter [930]===
# Topic 0: ['datum', 'learn', 'learning', 'task', 'problem', 'algorithm', 'set', 'method', 'feature', 'label']
# Topic 1: ['learning', 'policy', 'reinforcement', 'learn', 'state', 'system', 'control', 'agent', 'algorithm', 'dynamic']
# Topic 2: ['problem', 'online', 'regret', 'algorithm', 't', 'bandit', 'prediction', 'model', 'new', 'abstract']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'process', 'approach', 'variable', 'gaussian', 'bayesian']
# Topic 4: ['algorithm', 'problem', 'function', 'optimization', 'gradient', 'method', 'edu', 'convex', 'stochastic', 'convergence']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'y', 'p', 'o', 'i', 'd']
# Topic 6: ['neuron', 'model', 'cell', 'neural', 'brain', 'activity', 'information', 'university', 'time', 'spike']
# Topic 7: ['object', 'system', 'image', 'recognition', 'model', 'visual', 'speech', 'input', 'information', 'representation']
# Topic 8: ['network', 'model', 'deep', 'neural', 'image', 'learning', 'task', 'learn', 'train', 'training']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'weight', 'training', 'learn', 'state', 'learning']
# Iter [940]===
# Topic 0: ['datum', 'learning', 'learn', 'problem', 'task', 'method', 'algorithm', 'university', 'feature', 'label']
# Topic 1: ['learning', 'policy', 'learn', 'reinforcement', 'state', 'system', 'agent', 'control', 'dynamic', 'algorithm']
# Topic 2: ['online', 'algorithm', 'regret', 'problem', 't', 'bandit', 'model', 'prediction', 'new', 's']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'variable', 'approach', 'university', 'gaussian', 'process', 'bayesian']
# Topic 4: ['algorithm', 'function', 'problem', 'optimization', 'gradient', 'method', 'convex', 'edu', 'convergence', 'stochastic']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'y', 'i', 'p', 'o', 'r']
# Topic 6: ['neuron', 'model', 'cell', 'neural', 'brain', 'activity', 'information', 'university', 'spike', 'system']
# Topic 7: ['object', 'system', 'visual', 'image', 'recognition', 'model', 'speech', 'representation', 'information', 'd']
# Topic 8: ['network', 'model', 'deep', 'image', 'neural', 'learning', 'task', 'train', 'learn', 'training']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'weight', 'training', 'learn', 'system', 'function']
# Iter [950]===
# Topic 0: ['datum', 'learning', 'learn', 'problem', 'algorithm', 'task', 'method', 'set', 'feature', 'label']
# Topic 1: ['learning', 'learn', 'policy', 'reinforcement', 'state', 'system', 'control', 'agent', 'dynamic', 'algorithm']
# Topic 2: ['problem', 'online', 'algorithm', 'regret', 't', 'prediction', 'bandit', 'university', 'bound', 's']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'variable', 'gaussian', 'process', 'university', 'approach', 'bayesian']
# Topic 4: ['algorithm', 'problem', 'function', 'gradient', 'optimization', 'method', 'convex', 'edu', 'stochastic', 'convergence']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'i', 'y', 'p', 'e', 'd']
# Topic 6: ['neuron', 'model', 'neural', 'cell', 'activity', 'brain', 'information', 'university', 'system', 'study']
# Topic 7: ['object', 'system', 'image', 'recognition', 'visual', 'model', 'speech', 'information', 'base', 'abstract']
# Topic 8: ['model', 'network', 'deep', 'neural', 'image', 'task', 'learning', 'train', 'representation', 'learn']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'weight', 'learn', 'system', 'function', 'training']
# Iter [960]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'algorithm', 'task', 'method', 'set', 'edu', 'label']
# Topic 1: ['learning', 'policy', 'learn', 'reinforcement', 'state', 'system', 'agent', 'control', 'dynamic', 'model']
# Topic 2: ['algorithm', 'problem', 'online', 'regret', 't', 'prediction', 'bandit', 's', 'bound', 'new']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'process', 'variable', 'university', 'gaussian', 'bayesian', 'estimate']
# Topic 4: ['algorithm', 'function', 'problem', 'gradient', 'optimization', 'method', 'learning', 'convex', 'edu', 'convergence']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'y', 'i', 'd', 'o', 'p']
# Topic 6: ['neuron', 'model', 'cell', 'neural', 'brain', 'activity', 'information', 'university', 'spike', 'study']
# Topic 7: ['object', 'system', 'image', 'recognition', 'visual', 'model', 'speech', 'information', 'd', 'input']
# Topic 8: ['network', 'model', 'deep', 'neural', 'image', 'task', 'learn', 'learning', 'train', 'representation']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'learn', 'weight', 'training', 'system', 'state']
# Iter [970]===
# Topic 0: ['datum', 'learn', 'learning', 'algorithm', 'problem', 'task', 'method', 'set', 'feature', 'label']
# Topic 1: ['learning', 'learn', 'policy', 'reinforcement', 'state', 'system', 'agent', 'control', 'dynamic', 'model']
# Topic 2: ['problem', 'online', 'algorithm', 'regret', 't', 'bandit', 'prediction', 'setting', 'bound', 'good']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'variable', 'process', 'gaussian', 'approach', 'bayesian']
# Topic 4: ['algorithm', 'problem', 'function', 'optimization', 'gradient', 'method', 'convex', 'convergence', 'edu', 'stochastic']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'y', 'e', 'i', 'p', 'd']
# Topic 6: ['neuron', 'model', 'cell', 'neural', 'brain', 'activity', 'information', 'university', 'spike', 'study']
# Topic 7: ['object', 'system', 'image', 'visual', 'recognition', 'model', 'speech', 'input', 'representation', 'd']
# Topic 8: ['network', 'model', 'deep', 'image', 'neural', 'learning', 'task', 'learn', 'train', 'training']
# Topic 9: ['network', 'neural', 'input', 'unit', 'weight', 'learn', 'output', 'system', 'training', 'function']
# Iter [980]===
# Topic 0: ['datum', 'learn', 'learning', 'problem', 'algorithm', 'method', 'task', 'feature', 'set', 'label']
# Topic 1: ['learning', 'learn', 'policy', 'reinforcement', 'state', 'control', 'system', 'agent', 'dynamic', 'environment']
# Topic 2: ['problem', 'online', 'algorithm', 'regret', 't', 'prediction', 'bandit', 'new', 'decision', 's']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'variable', 'process', 'gaussian', 'approach', 'bayesian']
# Topic 4: ['algorithm', 'function', 'problem', 'optimization', 'gradient', 'method', 'convex', 'learning', 'convergence', 'stochastic']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'y', 'p', 'd', 'i', 'r']
# Topic 6: ['neuron', 'model', 'neural', 'cell', 'brain', 'activity', 'university', 'information', 'spike', 'response']
# Topic 7: ['object', 'system', 'image', 'recognition', 'visual', 'model', 'speech', 'input', 'information', 'd']
# Topic 8: ['network', 'model', 'deep', 'image', 'neural', 'task', 'learning', 'learn', 'training', 'train']
# Topic 9: ['network', 'neural', 'input', 'unit', 'output', 'weight', 'training', 'learn', 'system', 'state']
# Iter [990]===
# Topic 0: ['datum', 'learn', 'learning', 'algorithm', 'task', 'method', 'problem', 'feature', 'label', 'set']
# Topic 1: ['learning', 'policy', 'learn', 'reinforcement', 'state', 'system', 'agent', 'control', 'dynamic', 'model']
# Topic 2: ['online', 'algorithm', 'problem', 'regret', 't', 'prediction', 'bandit', 'decision', 'new', 'arm']
# Topic 3: ['model', 'distribution', 'datum', 'inference', 'university', 'variable', 'process', 'gaussian', 'estimate', 'method']
# Topic 4: ['algorithm', 'function', 'problem', 'optimization', 'gradient', 'method', 'edu', 'convex', 'convergence', 'stochastic']
# Topic 5: ['x', 'n', 'k', 'matrix', 't', 'y', 'i', 'd', 'p', 'r']
# Topic 6: ['neuron', 'model', 'neural', 'cell', 'brain', 'activity', 'information', 'university', 'spike', 'study']
# Topic 7: ['object', 'system', 'image', 'visual', 'recognition', 'model', 'speech', 'input', 'problem', 'information']
# Topic 8: ['deep', 'network', 'model', 'neural', 'image', 'learning', 'task', 'learn', 'train', 'representation']
# Topic 9: ['network', 'neural', 'input', 'unit', 'learn', 'output', 'weight', 'training', 'system', 'error']
